# %% [markdown]
# <a href="https://colab.research.google.com/github/alimoorreza/CS181-Fall26-Notebook-1/blob/main/notebook_1_whitening_starter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from PIL import Image, ImageFilter, ImageDraw
import numpy as np
import matplotlib.pyplot as plt

img_pil       = Image.open('/content/drive/MyDrive/cs181_fall26/notebook_assignments/assignment1/input_images/first_photograph.png')
img_pil_array = np.asarray(img_pil)

plt.figure(figsize=(4,4)) #figure size (4 inch, 4 inch)
plt.imshow(img_pil_array, cmap='gray')
plt.title('First photograph')
img_pil_array.shape
# Out:
# (400, 400)

# %%
# Step 1: compute the mean and variance of the gray-scale image 'img_pil'
im_mean     = -1
im_variance = -1
im_std      = -1



# calculate mean of the grayscale image 'img_pil'
print("image mean:",im_mean)
# YOUR CODE
# ...
# ...
# ...

# calculate variance of the grayscale image 'img_pil'
print("image variance:",im_variance)
# YOUR CODE
# ...
# ...
# ...

# calculate std of the grayscale image 'img_pil'
print("image standard deviation:",im_std)
# YOUR CODE
# ...
# ...
# ...
# Out:
# image mean: 122.095525
# image variance: 7943.379962474358
# image standard deviation: 89.12564144214817

# %%
# Step 2: transform each pixel value separately using the above two computed statistics μ (mean) and σ (standard deviation)
im_whiten = Image.new('L', (img_pil.width,img_pil.height), color=0)

for x in range(img_pil.width):
  for y in range(img_pil.height):

    # --------------------------------------------------------
    # HINT: apply the whitening equation (Equation#3 in the readme file on Github)
    # HINT: you may need to use PIL methods: putpixel.getpixel() and img_pil.putpixel()
    # YOUR CODE
    # ...
    # ...
    # ...
    # --------------------------------------------------------
    #print('')



# diplay the image
# --------------------------------------------------------
fig, axes = plt.subplots(1,2, figsize=(8, 8))
ax = axes[0]
ax.imshow(img_pil, cmap='gray')
ax.set_title('First photograph original')
ax = axes[1]
ax.imshow(im_whiten, cmap='gray')
ax.set_title('First photograph whitened')

# --------------------------------------------------------
# Out:
# Text(0.5, 1.0, 'First photograph whitened')

# %%
# Verification code: mean, variance, standard deviation
# You don't need to do anything here. I will verify your calculation using this code snippet below
# Out:
# image mean: 0
# image variance: 1
# <ipython-input-7-9bb40219ebd6>:4: DeprecationWarning: Please import `loadmat` from the `scipy.io.matlab` namespace; the `scipy.io.matlab.mio` namespace is deprecated and will be removed in SciPy 2.0.0.
#   from scipy.io.matlab.mio import loadmat
